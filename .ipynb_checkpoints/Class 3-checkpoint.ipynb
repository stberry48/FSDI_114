# %% [markdown]
# # Linked Lists
#
# In today's class, we're going to introduce the two varieties of linked lists:
# 1. Singly Linked Lists (uni-directional)
# 2. Doubly Linked Lists (bi-directional)

# %%
# How python does it
help{[]}
# Out:
#   Cell In[1], line 2
#     help{[]}
#         ^
# SyntaxError: invalid syntax

# %%
help([])
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
# ...

# %%
mylist = []
#printing an empty list:
print(mylist)

mylist.append(0)
# printing a list with exactly one element:
print(mylist)

mylist.append(1)
# printing a list with more than one element:
print(mylist)
# Out:
# []
# [0]
# [0, 1]

# %%
# From scratch implementation of Singly Linked Lists

class SinglyLinkedList:
    class __Node:
        def __init__(self, data):
            self.data = data
            self.next = None

    def __init__(self):
        self.head = None
        self.tail = None

    def append(self, value):
        new_node = self.__Node(value)
        if not self.head:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node

    def insert(self, index, value):
        new_node = self.__Node(value)  # create new node with the incoming value
        if index == 0:                 # if there is no head:
            new_node.next = self.head      # make it so that my new node is now the head node
            self.head = new_node           # also make it so that my new node is now the head node
            if not self.tail:              # otherwise
                self.tail = new_node        # if the index i received is 0 replace the head reference to point to my new node
        else:                           # Intitialize a variable called current which starts by pointing at the head node
            current = self.head          # intialize a variable called previous which starts by pointing at none
            for _ in range(index - 1):
                if current is None:
                    raise IndexError("Index out of range")
                current = current.next
            if current is None:
                raise IndexError("Index out of range")
            new_node.next = current.next
            current.next = new_node
            if new_node.next is None:
                self.tail = new_node

    def __str__(self):
        out = "["
        current = self.head
        if current:
            out += "%s" % repr(current.data)
            while current.next:
                current = current.next
                out += ", %s" % repr(current.data)
        out += "]"
        return out

    def print_list(self):
        current = self.head
        while current:
            print(current.value, end=" -> ")
            current = current.next
        print("None")

  
        
        #condition 1 there must be a next node to loop into
# condition 2 I have not yet found the target index (this is so long as count does not equal index)
        #these are the instructions that happen every time I loop:1. I update previous to point to the same thing current is pointing to
# I update current

# %%
sll = SinglyLinkedList()

# When the list is empty:
print(sll)

# When the list contains exactly one element
sll.append(0)
print(sll)

# when the list contains more than one element
sll.append(1)
print(sll)
# Out:
# []
# [0]
# [0, 1]

# %%
# with Python lists
newlist = []

# inserting at index 1000 on an empty list
newlist.insert(1000, "A")

print(newlist)

# replacing the head node
newlist.insert(0, "Z")
print(newlist)
# when the provided index is eaxctly to 0, we are replacing the head node with insert

# inserting anywhere between head and tail
newlist.insert(1, 1)
print(newlist)
# Out:
# ['A']
# ['Z', 'A']
# ['Z', 1, 'A']
